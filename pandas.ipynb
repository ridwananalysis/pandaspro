# %%
pip install seaborn
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for matplotlib!=3.6.1,>=3.3 from https://files.pythonhosted.org/packages/b6/4d/952bd694c5ab4c7938434d53e8eda1ab98940dabc36ce0f69e49503b4583/matplotlib-3.8.1-cp39-cp39-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/ba/e5/05fdbe3a7570777464595ab1de9047adef7de99659cf969dbfe007e165cb/contourpy-1.2.0-cp39-cp39-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sportify_review = pd.read_csv('./spotify - spotify.csv', index_col='Date')
sportify_review
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
sportify_review.plot(kind='line', x='Date')
plt.title('sportify_review data')
plt.show()

# %%
sportify_review.plot(kind='hist')
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.title('most stream songs ')
sns.lineplot(data=sportify_review['Shape of You'], label= 'shape of You')
sns.lineplot(data=sportify_review['HUMBLE.'], label= 'HUMBLE.')
# Out:
# <Axes: title={'center': 'most stream songs '}, xlabel='Date', ylabel='Shape of You'>
